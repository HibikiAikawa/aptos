# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/pancakeswap/pancakeswap_pair_log.csv', index_col=0)

# %%
df.head()
# Out:
#     version  creation_number  \
# 0  11447126                4
# 1  11699506                4
# 2  11767067                4
# 3  12276333                4
# 4  12302620                4
#
#                                      account_address  sequence_number  \
# 0  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...                1
# 1  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...                2
# 2  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...                3
# 3  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...                4
# 4  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...                5
#
#                                                 type  \
# 0  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...
# 1  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...
# 2  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...
# 3  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...
# 4  0xc7efb4076dbe143cbcd98cfaaa929ecfc8f299203dff...
#
#                       token_x  \
# ...
